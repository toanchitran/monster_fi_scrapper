# %% [markdown]
# ### TRAN CHI TOAN - toanchitran2302@gmail.com

# %%
from datetime import date
today = date.today().isoformat()
from bs4 import BeautifulSoup 
import requests
import re 
from time import sleep
import pandas as pd
from datetime import date

def monster (job_query = None, location_query=''):
    
    
    if job_query is None:
        job_query = 'data-analytics'
    else:
        job_query = job_query.split()
        job_query= '-'.join(w for w in job_query)
    
    if location_query is not None:
        location_query = location_query.split()
        location_query = '-'.join(w for w in location_query)
        
        
    #Get job detail job description fuction
    def job(url):
        job_page = requests.get(url)
        job_soup = BeautifulSoup(job_page.text, 'lxml')
        job_desc = job_soup.find('div', attrs={'id':'JobDescription'}).text
        return job_desc

    # Clean text
    def clean_text(text):
        lines = (line.strip() for line in text.splitlines()) # break into lines
        
        chunks = (phrase.strip() for line in lines for phrase in line.split("  ")) # break multi-headlines into a line each
    
        def chunk_space(chunk):
            chunk_out = chunk + ' ' # Need to fix spacing issue
            return chunk_out  
        
    
        text = ''.join(chunk_space(chunk) for chunk in chunks if chunk).encode('utf-8') # Get rid of all blank lines and ends of line
        
        
        # Now clean out all of the unicode junk (this line works great!!!)
        
        try:
            text = text.decode('unicode_escape').encode('ascii', 'ignore') # Need this as some websites aren't formatted
        except:                                                            # in a way that this works, can occasionally throw
            return                                                         # an exception
        return text



    # Scrapt the first page to find the number of jobs 
    base_URL= ''.join(['https://www.monster.fi/tyopaikat/haku/?q='+job_query+'&where='+location_query])
    base_page = requests.get(base_URL)
    base_soup = BeautifulSoup(base_page.text, 'html.parser')
    number_job = sum(int(i) for i in re.findall('\d+', base_soup.find('h2', attrs={'class':'figure'}).text))

    page_num = int(number_job/20)

    #Scrapt all the job
    crawl_page = ''.join([base_URL, '&page=', str(page_num)])
    page = requests.get(crawl_page)
    soup = BeautifulSoup(page.text, 'html.parser')

    # We need those dataframe to store information on company, job title, link, location and job description
    company = pd.DataFrame(columns=['Company'])
    location = pd.DataFrame(columns=['Location'])
    title = pd.DataFrame(columns=['Title'])
    URL = pd.DataFrame(columns=['URL'])
    job_description = pd.DataFrame(columns=['Job Description'])
    final_query= pd.DataFrame(columns=['Job Query'])
    links = []
    
    #Append Job Query
    

    # Find companies
    companies = soup.findAll(name='div', attrs={'class':'company'})

    # Find job titles
    titles = soup.findAll(name='h2', attrs={'class':'title'})

    # Find job locations
    locations = soup.findAll(name='div', attrs={'class':'location'})

    # Append all companies into companies dataframe
    for a in companies:
        comp=a.text.strip()
        company= company.append({'Company':comp},ignore_index=True)

    # Append all job locations to locations dataframe
    for b in locations:
        loc = b.text.strip()
        if loc != 'Alue tai paikkakunta\n\nx':
            location= location.append({'Location':loc}, ignore_index=True)


    for c in titles:
        link = c.find('a').attrs['href']
        links.append(link)
        title = title.append({'Title': c.text.strip()}, ignore_index=True)
        URL=URL.append({'URL':link}, ignore_index=True)
        final_query = final_query.append({'Job Query':job_query}, ignore_index=True)
   
    for e in links:
        job_desc_l = job(e)
        job_clean = clean_text(job_desc_l)
        job_clean = job_clean.replace("#jobBodyContent ul { 		margin-bottom: 13px; 		line-height: 16px; 	}", "")
        job_clean = job_clean.replace("#ejb_SubHdTxt, .ejb_SubHdTxt { background-color: #f1f1f1;} 		.addthis_button {font-size:8pt;} div#content{ font-size: 12px; /*font-family: Arial, Helvetica, sans-serif; */ 			line-height: 20px; 			/*width: 758px; */ 			overflow: hidden; 		} 		img#barona_top_banner{ 			width: 100%; 			height: auto; 			margin-bottom: 30px; 		}	 		div#content_text{ 			margin-left: 40px; 			margin-right: 40px; 		} 		div#barona-text-area-padding{ 			padding-bottom: 40px; 		} 		div#content_text a{font-size: 14px; font-weight: bold; color: #0d51b4; text-decoration: none;} div#content_text h1{font-size: 26px; font-weight: bold; margin-bottom: 30px;} 	 		div#content_text h2{font-size: 16px; font-weight: bold; } 		div#content_text span.company-title{font-weight: bold; } div#employer-company-card{ 			border-top: 1px solid #dedede; 			padding-top: 40px; 			padding-bottom: 40px;		 		} 		img#barona-employer-logo{ 			max-width: 185px; 			height: auto; 			margin-bottom: 20px; 		}	 		div#barona-company-card{ 			border-top: 1px solid #dedede; 			padding-top: 40px; 			padding-bottom: 40px;		 		} 		img#barona-logo{ 			max-width: 185px; 			height: auto; 			margin-bottom: 20px; 		} ", "")
        job_description = job_description.append({'Job Description':job_clean}, ignore_index=True)
        sleep(1)

    job=pd.concat([final_query, company, location, title, URL, job_description], axis=1)
    
    # Uncomment line below to create a csv file with the new job found
    #job.to_csv('monster_fi_'+today+'_'+job_query''_'+location_query+'.csv', encoding='utf-8')   
    
    return job

# %%
monster()
# Out:
#          Job Query                                 Company        Location  \
# 0   data-analytics                           Academic Work        Helsinki
# 1   data-analytics                                  Nordea        Helsinki
# 2   data-analytics                               Accenture        Helsinki
# 3   data-analytics                          Stora Enso Oyj        Helsinki
# 4   data-analytics                             Avaintec Oy        Helsinki
# 5   data-analytics                                  Nordea        Helsinki
# 6   data-analytics                               Accenture        Helsinki
# 7   data-analytics                                  Patria           Espoo
# 8   data-analytics                          Danfoss Drives         Tampere
# 9   data-analytics                          Danfoss Drives          Vantaa
# 10  data-analytics                          Danfoss Drives           Espoo
# 11  data-analytics                               Eniram Oy        Helsinki
# 12  data-analytics                           Academic Work        Helsinki
# 13  data-analytics                               Accenture        Helsinki
# 14  data-analytics                                  FROSMO        Helsinki
# 15  data-analytics                                 Vaisala        Helsinki
# 16  data-analytics            Envera Oy / co Mercuri Urval           Espoo
# 17  data-analytics                       Management Events        Helsinki
# 18  data-analytics                                Deloitte        HELSINKI
# 19  data-analytics                                     MPS        Helsinki
# 20  data-analytics                         MOIA Finland Oy           Espoo
# 21  data-analytics                               Helvar Oy         Uusimaa
# 22  data-analytics                          Danfoss Drives           Espoo
# 23  data-analytics                          Danfoss Drives         Tampere
# 24  data-analytics                          Danfoss Drives           Vaasa
# 25  data-analytics                     Vaisto Solutions Oy         Tampere
# 26  data-analytics                          Stora Enso Oyj         Varkaus
# 27  data-analytics  CSC - Tieteen tietotekniikan keskus Oy           Espoo
# 28  data-analytics                               Helvar Oy         Uusimaa
# 29  data-analytics                               Helvar Oy         Uusimaa
# 30  data-analytics                               Accenture        Helsinki
# 31  data-analytics                               Accenture        Helsinki
# 32  data-analytics                                Wärtsilä           Turku
# 33  data-analytics                                Wärtsilä           Vaasa
# 34  data-analytics                                Wärtsilä        Helsinki
# 35  data-analytics                         u-blox Espoo Oy           Espoo
# 36  data-analytics                      aTalent Recruiting           Espoo
# 37  data-analytics                                Deloitte        HELSINKI
# 38  data-analytics                         Poolia Suomi Oy        Helsinki
# 39  data-analytics                                  Barona          Vantaa
# 40  data-analytics                              Musopia Oy        Helsinki
# 41  data-analytics  CSC - Tieteen tietotekniikan keskus Oy           Espoo
# 42  data-analytics                         Electronic Arts        Helsinki
# 43  data-analytics                    3DS Dassault Systems  Finland, Espoo
# 44  data-analytics                           Expedia, Inc.        Helsinki
# 45  data-analytics                    3DS Dassault Systems           Espoo
# 46  data-analytics                           Expedia, Inc.        Helsinki
# 47  data-analytics                              Feedbackly        Helsinki
#
#                                                 Title  \
# 0   Osa-aikainen Data Scientist / Data Analyst, Ho...
# 1                        Analytics Business Developer
# 2           Digital Analytics Consultants to Helsinki
# 3   IT Development Manager, reporting and analytic...
# 4                Chinese Speaking Junior Data Analyst
# 5                         BI Specialist/ Data Analyst
# 6                         AI -and Big data -engineers
# 7          Data Mining -asiantuntija / Systems, Espoo
# 8                     Digital Data Insight Specialist
# 9                     Digital Data Insight Specialist
# 10                    Digital Data Insight Specialist
# 11                                     Data Scientist
# 12  Product Owner (Data platforms) to Technopolis,...
# 13                             Junior SAS -developers
# 14                          Technical Project Manager
# 15               Website and Online Marketing Manager
# 16                             HEAD OF GROWTH HACKING
# 17                  Management Trainee, Group Finance
# 18                 Trainee (Human Capital Consulting)
# 19  Category Management Specialist / Paulig Coffee...
# 20                            Software Engineer (m/f)
# 21              Software Engineer - Cloud Development
# 22                                       Digital Lead
# 23                                       Digital Lead
# 24                                       Digital Lead
# 25                 Machine Learning Software Engineer
# 26                                          Purchaser
# 27                                  System Specialist
# 28  Embedded Software Developer - Lighting Intelli...
# 29                             Software Test Engineer
# 30                           SAP Logistics Consultant
# 31                             SAP Finance Consultant
# 32                            Solution Architect, PLM
# 33                            Solution Architect, PLM
# 34                            Solution Architect, PLM
# 35                      Inside Sales, Northern Europe
# 36                         Canter: Software Developer
# 37         Trainee (Strategy & Operations Consulting)
# 38       Digital Marketing and Communications Trainee
# 39                               Controller Assistant
# 44  https://avoimettyopaikat.monster.fi/travel-con...
# 45  https://avoimettyopaikat.monster.fi/senior-bus...
# 46  https://avoimettyopaikat.monster.fi/sales-mana...
# 47  https://avoimettyopaikat.monster.fi/marketing-...
#
#                                       Job Description
# 0   Houston Analytics on tiedolla johtamisen ammat...
# 1   Nordea Life Assurance Finland is looking for a...
# 2    We are looking for Digital Analytics Consulta...
# 3   IT Development Manager, reporting and analytic...
# 4   We are looking for a Junior Data Analyst who i...
# 5   We are looking for a Business Intelligent Spec...
# 6    Looking for AI -and Big data -engineers to ou...
# 7   Patriassa puolustus-, turvallisuus- ja ilmailu...
# 8   Digital Data Insight SpecialistEspoo, Vantaa, ...
# 9   Digital Data Insight SpecialistEspoo, Vantaa, ...
# 10  Digital Data Insight SpecialistEspoo, Vantaa, ...
# 11  We are now looking for aData ScientistTo join ...
# 12  As a Product Owner you are responsible for the...
# 13   Be yourself, Make a difference  Make a differ...
# 14  Are you looking for a job that challenges you,...
# 15  Location: HelsinkiWe are looking for: We are l...
# 16  HEAD OF GROWTH HACKINGDigital marketing guru -...
# 17  Are you eager to join a Global Finance team an...
# 18  We are now searching for a Trainee to join our...
# 19  At Paulig, we are united in the quest of Explo...
# 20  We want to hire Software Engineers to contribu...
# 21  Summer is here! And now is the perfect time to...
# 22  Digital LeadEspoo, Vantaa, Vaasa, Tampere (FI)...
# 23  Digital LeadEspoo, Vantaa, Vaasa, Tampere (FI)...
# 24  Digital LeadEspoo, Vantaa, Vaasa, Tampere (FI)...
# 25  MACHINE LEARNING SOFTWARE ENGINEER  TampereAre...
# 26  Purchaser, Varkaus Stora Enso Sourcing and Log...
# 27  We are looking for enthusiastic system special...
# 28  Autumnis here! And now is the perfect time to ...
# 29  Summer is here! And now is the perfect time to...
# 30   Are you Accenture's future SAP Logistics tale...
# 31   Are you Accenture's new SAP Finance Consultan...
# 32  AT WRTSIL, PEOPLE ARE THE ULTIMATEPOWER SOURCE...
# 33  AT WRTSIL, PEOPLE ARE THE ULTIMATEPOWER SOURCE...
# 34  AT WRTSIL, PEOPLE ARE THE ULTIMATEPOWER SOURCE...
# 35  Swiss-based u-blox (SIX:UBXN) is the global le...
# 36  Type: PermanentPreferred background: Experienc...
# 37  We are now searching for trainees to work in o...
# 38  Etsimme nyt digitaalisen markkinoinnin ja vies...
# 39  Controller Assistant, Vantaa If you are intere...
# 40  Senior Mobile Developer - music, Helsinki You ...
# 41  We are looking for enthusiastic system special...
# 42  We are EAAnd we make games  how cool is that? ...
# 43  Imagine new horizons.... If you have great rap...
# 44  EgenciaEach year Egencia helps thousands of co...
# 45  Imagine New Horizons.... Senior Business Consu...
# 46  EgenciaAre you an energetic, motivated new bus...
# 47  Hola!We are looking for a talented marketing m...
